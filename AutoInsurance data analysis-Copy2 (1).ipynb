# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("AutoInsurance.csv")

# %%
df
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  ...  \
# 0     Bachelor           2/24/11         Employed      F   56274  ...
# 1     Bachelor           1/31/11       Unemployed      F       0  ...
# 2     Bachelor           2/19/11         Employed      F   48767  ...
# 3     Bachelor           1/20/11       Unemployed      M       0  ...
# 4     Bachelor          3/2/2011         Employed      M   43836  ...
# ...        ...               ...              ...    ...     ...  ...
# 9129  Bachelor         10/2/2011         Employed      M   71941  ...
# 9130   College         12/2/2011         Employed      F   21604  ...
# 9131  Bachelor          6/2/2011       Unemployed      M       0  ...
# 9132   College          3/2/2011         Employed      M   21941  ...
# 9133   College           2/14/11       Unemployed      M       0  ...
#
#      Months Since Policy Inception Number of Open Complaints  \
# 0                                5                         0
# 1                               42                         0
# 2                               38                         0
# 3                               65                         0
# 4                               44                         0
# ...                            ...                       ...
# 9129                            89                         0
# 9130                            28                         0
# 9131                            37                         3
# 9132                             3                         0
# 9133                            90                         0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#       Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0             Agent         384.811147   Two-Door Car      Medsize
# 1             Agent        1131.464935  Four-Door Car      Medsize
# 2             Agent         566.472247   Two-Door Car      Medsize
# 3       Call Center         529.881344            SUV      Medsize
# 4             Agent         138.130879  Four-Door Car      Medsize
# ...             ...                ...            ...          ...
# 9129            Web         198.234764  Four-Door Car      Medsize
# 9130         Branch         379.200000  Four-Door Car      Medsize
# 9131         Branch         790.784983  Four-Door Car      Medsize
# 9132         Branch         691.200000  Four-Door Car        Large
# 9133    Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
#Exploretory Data Analysis(EDA)

# %%
#import visualisation Libraries
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB

# %%
# Checking Data type of the columns

# %%
#checking null values
df.isnull().sum()
# Out:
# Customer                         0
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
# No Missing values

# %%
df.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# 75%                  23.000000                      71.000000
# max                  35.000000                      99.000000
#
#        Number of Open Complaints  Number of Policies  Total Claim Amount
# count                9134.000000         9134.000000         9134.000000
# mean                    0.384388            2.966170          434.088794
# std                     0.910384            2.390182          290.500092
# min                     0.000000            1.000000            0.099007
# 25%                     0.000000            1.000000          272.258244
# 50%                     0.000000            2.000000          383.945434
# 75%                     0.000000            4.000000          547.514839
# max                     5.000000            9.000000         2893.239678

# %%
#We can see mean median std of all numerical columns. There is only 8 numerical columns in the Dataset

# %%
df['Customer'].nunique()
# Out:
# 9134

# %%
df.shape
# Out:
# (9134, 24)

# %%
# Since this columns represent unique id of each customer. We drop this column

# %%
df.drop(["Customer"], axis=1, inplace=True)

# %%
df
# Out:
#            State  Customer Lifetime Value Response  Coverage Education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      Effective To Date EmploymentStatus Gender  Income Location Code  ...  \
# 0              2/24/11         Employed      F   56274      Suburban  ...
# 1              1/31/11       Unemployed      F       0      Suburban  ...
# 2              2/19/11         Employed      F   48767      Suburban  ...
# 3              1/20/11       Unemployed      M       0      Suburban  ...
# 4             3/2/2011         Employed      M   43836         Rural  ...
# ...                ...              ...    ...     ...           ...  ...
# 9129         10/2/2011         Employed      M   71941         Urban  ...
# 9130         12/2/2011         Employed      F   21604      Suburban  ...
# 9131          6/2/2011       Unemployed      M       0      Suburban  ...
# 9132          3/2/2011         Employed      M   21941      Suburban  ...
# 9133           2/14/11       Unemployed      M       0      Suburban  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 0                                5                          0
# 1                               42                          0
# 2                               38                          0
# 3                               65                          0
# 4                               44                          0
# ...                            ...                        ...
# 9129                            89                          0
# 9130                            28                          0
# 9131                            37                          3
# 9132                             3                          0
# 9133                            90                          0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#      Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0            Agent         384.811147   Two-Door Car      Medsize
# 1            Agent        1131.464935  Four-Door Car      Medsize
# 2            Agent         566.472247   Two-Door Car      Medsize
# 3      Call Center         529.881344            SUV      Medsize
# 4            Agent         138.130879  Four-Door Car      Medsize
# ...            ...                ...            ...          ...
# 9129           Web         198.234764  Four-Door Car      Medsize
# 9130        Branch         379.200000  Four-Door Car      Medsize
# 9131        Branch         790.784983  Four-Door Car      Medsize
# 9132        Branch         691.200000  Four-Door Car        Large
# 9133   Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 23 columns]

# %%
# List of categorical columns to loop through
categorical_columns = ['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus', 'Gender', 'Location Code', 'Marital Status', 'Number of Open Complaints', 'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']

# Set the figure size
plt.figure(figsize=(30,60))

# Create a for loop to plot countplots for each column
for i, column in enumerate(categorical_columns):
    plt.subplot(8, 2, i + 1)  # Create a subplot for each column
    sns.countplot(df['Location code'])  # Plot the countplot for the column
    plt.title(f'Countplot of {column}')  # Set the title
    plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.tight_layout()  # Ensure proper spacing between subplots
plt.show()  # Show the plots
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'example_column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 10
#       8 for i, column in enumerate(categorical_columns):
#       9     plt.subplot(8, 2, i + 1)  # Create a subplot for each column
# ---> 10     sns.countplot(df['example_column'])  # Plot the countplot for the column
#      11     plt.title(f'Countplot of {column}')  # Set the title
#      12     plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'example_column'

# %%
#We have only 5 states data and Most information is for the state of California

# %%
#Most customer Response data is No

# %%
# The majority of coverage types are basic, while premium coverage types are relatively scarce

# %%
#The majority of customers have educational backgrounds of bachelor's degrees, some attended college, high school, or have education levels below high school, while a relatively small number of customers hold master's or doctoral degrees.

# %%
df['Effective To Date'].nunique()
# Out:
# 59

# %%
df['Effective To Date']
# Out:
# 0         2/24/11
# 1         1/31/11
# 2         2/19/11
# 3         1/20/11
# 4        3/2/2011
#           ...
# 9129    10/2/2011
# 9130    12/2/2011
# 9131     6/2/2011
# 9132     3/2/2011
# 9133      2/14/11
# Name: Effective To Date, Length: 9134, dtype: object

# %%
#conovert this date in datetime format using pandas
df['Effective To Date'] = pd.to_datetime(df['Effective To Date'])

# %%
df['Effective To Date']
# Out:
# 0      2011-02-24
# 1      2011-01-31
# 2      2011-02-19
# 3      2011-01-20
# 4      2011-03-02
#           ...
# 9129   2011-10-02
# 9130   2011-12-02
# 9131   2011-06-02
# 9132   2011-03-02
# 9133   2011-02-14
# Name: Effective To Date, Length: 9134, dtype: datetime64[ns]

# %%
df
# Out:
#            State  Customer Lifetime Value Response  Coverage Education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             23405.987980       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      Effective To Date EmploymentStatus Gender  Income Location Code  ...  \
# 0           2011-02-24         Employed      F   56274      Suburban  ...
# 1           2011-01-31       Unemployed      F       0      Suburban  ...
# 2           2011-02-19         Employed      F   48767      Suburban  ...
# 3           2011-01-20       Unemployed      M       0      Suburban  ...
# 4           2011-03-02         Employed      M   43836         Rural  ...
# ...                ...              ...    ...     ...           ...  ...
# 9129        2011-10-02         Employed      M   71941         Urban  ...
# 9130        2011-12-02         Employed      F   21604      Suburban  ...
# 9131        2011-06-02       Unemployed      M       0      Suburban  ...
# 9132        2011-03-02         Employed      M   21941      Suburban  ...
# 9133        2011-02-14       Unemployed      M       0      Suburban  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 0                                5                          0
# 1                               42                          0
# 2                               38                          0
# 3                               65                          0
# 4                               44                          0
# ...                            ...                        ...
# 9129                            89                          0
# 9130                            28                          0
# 9131                            37                          3
# 9132                             3                          0
# 9133                            90                          0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#      Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0            Agent         384.811147   Two-Door Car      Medsize
# 1            Agent        1131.464935  Four-Door Car      Medsize
# 2            Agent         566.472247   Two-Door Car      Medsize
# 3      Call Center         529.881344            SUV      Medsize
# 4            Agent         138.130879  Four-Door Car      Medsize
# ...            ...                ...            ...          ...
# 9129           Web         198.234764  Four-Door Car      Medsize
# 9130        Branch         379.200000  Four-Door Car      Medsize
# 9131        Branch         790.784983  Four-Door Car      Medsize
# 9132        Branch         691.200000  Four-Door Car        Large
# 9133   Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 23 columns]

# %%
df.corr()
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.024366
# Income                                        0.024366  1.000000
# Monthly Premium Auto                          0.396262 -0.016665
# Months Since Last Claim                       0.011517 -0.026715
# Months Since Policy Inception                 0.009418 -0.000875
# Number of Open Complaints                    -0.036343  0.006408
# Number of Policies                            0.021955 -0.008656
# Total Claim Amount                            0.226451 -0.355254
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.396262                 0.011517
# Income                                    -0.016665                -0.026715
# Monthly Premium Auto                       1.000000                 0.005026
# Months Since Last Claim                    0.005026                 1.000000
# Months Since Policy Inception              0.020257                -0.042959
# Number of Open Complaints                 -0.013122                 0.005354
# Number of Policies                        -0.011233                 0.009136
# Total Claim Amount                         0.632017                 0.007563
#
#                                Months Since Policy Inception  \
# Customer Lifetime Value                             0.009418
# Income                                             -0.000875
# Monthly Premium Auto                                0.020257
# Months Since Last Claim                            -0.042959
# Months Since Policy Inception                       1.000000
# Number of Open Complaints                          -0.001158
# Number of Policies                                 -0.013333
# Total Claim Amount                                  0.003335
#
#                                Number of Open Complaints  Number of Policies  \
# Customer Lifetime Value                        -0.036343            0.021955
# Income                                          0.006408           -0.008656
# Monthly Premium Auto                           -0.013122           -0.011233
# Months Since Last Claim                         0.005354            0.009136
# Months Since Policy Inception                  -0.001158           -0.013333
# Number of Open Complaints                       1.000000            0.001498
# Number of Policies                              0.001498            1.000000
# Total Claim Amount                             -0.014241           -0.002354
#
#                                Total Claim Amount
# Customer Lifetime Value                  0.226451
# Income                                  -0.355254
# Monthly Premium Auto                     0.632017
# Months Since Last Claim                  0.007563
# Months Since Policy Inception            0.003335
# Number of Open Complaints               -0.014241
# Number of Policies                      -0.002354
# Total Claim Amount                       1.000000

# %%
#checking corrleation using heatmap
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
# There is a pair of features, Total Claim Amount and Monthly Premium Auto, with a correlation exceeding 0.5.

# %% [markdown]
# # Checking Outliers:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns

for column in numerical_columns:
    plt.figure(figsize=(8, 5))
    sns.boxplot(data=df, x=column)
    plt.show()

# %% [markdown]
# # Outlier Treatment

# %%
import pandas as pd
import numpy as np

def replace_outliers_with_whiskers(df, col_name):
    q1 = df[col_name].quantile(0.25)
    q3 = df[col_name].quantile(0.75)
    iqr = q3 - q1  # Interquartile range
    fence_low = q1 - 1.5 * iqr
    fence_high = q3 + 1.5 * iqr

    df[col_name] = np.where(df[col_name] < fence_low, fence_low, df[col_name])
    df[col_name] = np.where(df[col_name] > fence_high, fence_high, df[col_name])

list_out = ['Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Total Claim Amount',]

df_no_outliers = df.copy()  # Create a copy of the original DataFrame

for var in list_out:
    replace_outliers_with_whiskers(df_no_outliers, var)

# Print the shape of the resulting DataFrame after replacing outliers with whisker values
print(df_no_outliers.shape)
# Out:
# (9134, 23)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns
numerical_columns = df_no_outliers.select_dtypes(include=['int64', 'float64']).columns

for column in numerical_columns:
    plt.figure(figsize=(8, 5))
    sns.boxplot(data=df_no_outliers, x=column)
    plt.show()

# %%
# Now there is not outliers in the dataframe

# %%
df_no_outliers
# Out:
#            State  Customer Lifetime Value Response  Coverage Education  \
# 0     Washington              2763.519279       No     Basic  Bachelor
# 1        Arizona              6979.535903       No  Extended  Bachelor
# 2         Nevada             12887.431650       No   Premium  Bachelor
# 3     California              7645.861827       No     Basic  Bachelor
# 4     Washington              2813.692575       No     Basic  Bachelor
# ...          ...                      ...      ...       ...       ...
# 9129  California             16414.039912       No     Basic  Bachelor
# 9130  California              3096.511217      Yes  Extended   College
# 9131  California              8163.890428       No  Extended  Bachelor
# 9132  California              7524.442436       No  Extended   College
# 9133  California              2611.836866       No  Extended   College
#
#      Effective To Date EmploymentStatus Gender   Income Location Code  ...  \
# 0           2011-02-24         Employed      F  56274.0      Suburban  ...
# 1           2011-01-31       Unemployed      F      0.0      Suburban  ...
# 2           2011-02-19         Employed      F  48767.0      Suburban  ...
# 3           2011-01-20       Unemployed      M      0.0      Suburban  ...
# 4           2011-03-02         Employed      M  43836.0         Rural  ...
# ...                ...              ...    ...      ...           ...  ...
# 9129        2011-10-02         Employed      M  71941.0         Urban  ...
# 9130        2011-12-02         Employed      F  21604.0      Suburban  ...
# 9131        2011-06-02       Unemployed      M      0.0      Suburban  ...
# 9132        2011-03-02         Employed      M  21941.0      Suburban  ...
# 9133        2011-02-14       Unemployed      M      0.0      Suburban  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 0                              5.0                          0
# 1                             42.0                          0
# 2                             38.0                          0
# 3                             65.0                          0
# 4                             44.0                          0
# ...                            ...                        ...
# 9129                          89.0                          0
# 9130                          28.0                          0
# 9131                          37.0                          3
# 9132                           3.0                          0
# 9133                          90.0                          0
#
#       Number of Policies     Policy Type        Policy  Renew Offer Type  \
# 0                      1  Corporate Auto  Corporate L3            Offer1
# 1                      8   Personal Auto   Personal L3            Offer3
# 2                      2   Personal Auto   Personal L3            Offer1
# 3                      7  Corporate Auto  Corporate L2            Offer1
# 4                      1   Personal Auto   Personal L1            Offer1
# ...                  ...             ...           ...               ...
# 9129                   2   Personal Auto   Personal L1            Offer2
# 9130                   1  Corporate Auto  Corporate L3            Offer1
# 9131                   2  Corporate Auto  Corporate L2            Offer1
# 9132                   3   Personal Auto   Personal L2            Offer3
# 9133                   1  Corporate Auto  Corporate L3            Offer4
#
#      Sales Channel Total Claim Amount  Vehicle Class Vehicle Size
# 0            Agent         384.811147   Two-Door Car      Medsize
# 1            Agent         960.399730  Four-Door Car      Medsize
# 2            Agent         566.472247   Two-Door Car      Medsize
# 3      Call Center         529.881344            SUV      Medsize
# 4            Agent         138.130879  Four-Door Car      Medsize
# ...            ...                ...            ...          ...
# 9129           Web         198.234764  Four-Door Car      Medsize
# 9130        Branch         379.200000  Four-Door Car      Medsize
# 9131        Branch         790.784983  Four-Door Car      Medsize
# 9132        Branch         691.200000  Four-Door Car        Large
# 9133   Call Center         369.600000   Two-Door Car      Medsize
#
# [9134 rows x 23 columns]

# %% [markdown]
# # Converting categorical columns to numeric columns

# %%
# checking for categorical columns
categorical_columns=[]
for i in df_no_outliers.dtypes.index:
    if df_no_outliers.dtypes[i]=='object':
        categorical_columns.append(i)
print(categorical_columns)
# Out:
# ['State', 'Response', 'Coverage', 'Education', 'EmploymentStatus', 'Gender', 'Location Code', 'Marital Status', 'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size']

# %%
len(categorical_columns)
# Out:
# 14

# %%
categorical_columns.append("Effective To Date")

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in categorical_columns:
    df_no_outliers[i]=le.fit_transform(df_no_outliers[i]).astype(int)

# %%
df_no_outliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          9134 non-null   int32
#  1   Customer Lifetime Value        9134 non-null   float64
#  2   Response                       9134 non-null   int32
#  3   Coverage                       9134 non-null   int32
#  4   Education                      9134 non-null   int32
#  5   Effective To Date              9134 non-null   int32
#  6   EmploymentStatus               9134 non-null   int32
#  7   Gender                         9134 non-null   int32
#  8   Income                         9134 non-null   float64
#  9   Location Code                  9134 non-null   int32
#  10  Marital Status                 9134 non-null   int32
#  11  Monthly Premium Auto           9134 non-null   float64
#  12  Months Since Last Claim        9134 non-null   float64
#  13  Months Since Policy Inception  9134 non-null   float64
#  14  Number of Open Complaints      9134 non-null   int64
#  15  Number of Policies             9134 non-null   int64
#  16  Policy Type                    9134 non-null   int32
#  17  Policy                         9134 non-null   int32
#  18  Renew Offer Type               9134 non-null   int32
#  19  Sales Channel                  9134 non-null   int32
#  20  Total Claim Amount             9134 non-null   float64
#  21  Vehicle Class                  9134 non-null   int32
#  22  Vehicle Size                   9134 non-null   int32
# dtypes: float64(6), int32(15), int64(2)
# memory usage: 1.1 MB

# %% [markdown]
# # Declare feature vector and target variable

# %%
X = df_no_outliers.drop(['Customer Lifetime Value'], axis=1) # Data set of all independet variables

y = df_no_outliers['Customer Lifetime Value'] # Dataset of target variable

# %% [markdown]
# # Split data into training and test set

# %%
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
## Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
regressor.intercept_
#
print('Slope:' ,regressor.coef_)
print('Intercept:', regressor.intercept_)
# Out:
# Slope: [-1.86905848e+01 -2.54069941e+02 -1.30981642e+02  8.14182249e+01
#  -1.40289039e+00 -9.56956680e+01 -2.33491857e+01  2.77102468e-03
#  -6.13831199e+01 -1.03330856e+02  6.60742099e+01  4.26175728e+00
#  -1.07689986e+00 -2.14886055e+02  1.89585256e+02  2.54317517e+02
#  -5.21363322e+01 -2.63268399e+02 -1.54236829e+00 -2.62414220e-01
#   1.41655131e+01  1.24885716e+02]
# Intercept: 1143.9904795798448

# %%
import statsmodels.api as sm

# Add a constant
X_train_lm = sm.add_constant(X_train) # to add constant to the model

# %%
X_train_lm
# Out:
#       const  State  Response  Coverage  Education  Effective To Date  \
# 8607    1.0      1         1         1          1                 47
# 2121    1.0      3         0         0          1                 41
# 5361    1.0      1         0         1          4                  6
# 7003    1.0      3         0         2          0                  7
# 7416    1.0      1         1         1          4                 33
# ...     ...    ...       ...       ...        ...                ...
# 5734    1.0      1         0         0          1                 18
# 5191    1.0      1         1         0          1                 44
# 5390    1.0      1         0         1          3                 16
# 860     1.0      0         1         1          0                 37
# 7270    1.0      0         0         1          0                 16
#
#       EmploymentStatus  Gender   Income  Location Code  ...  \
# 8607                 1       1  66429.0              0  ...
# 2121                 4       0      0.0              1  ...
# 5361                 1       0  36094.0              2  ...
# 7003                 1       1  95102.0              0  ...
# 7416                 4       0      0.0              1  ...
# ...                ...     ...      ...            ...  ...
# 5734                 1       0  87957.0              1  ...
# 5191                 2       1  22520.0              1  ...
# 5390                 4       0      0.0              1  ...
# 860                  4       0      0.0              1  ...
# 7270                 1       1  78092.0              2  ...
#
#       Months Since Policy Inception  Number of Open Complaints  \
# 8607                           93.0                          0
# 2121                           70.0                          0
# 5361                           50.0                          1
# 7003                           73.0                          0
# 7416                           47.0                          0
# ...                             ...                        ...
# 5734                           63.0                          0
# 5191                           64.0                          0
# 5390                            4.0                          0
# 860                            56.0                          0
# 7270                           13.0                          0
#
#       Number of Policies  Policy Type  Policy  Renew Offer Type  \
# 8607                   1            0       2                 1
# 2121                   4            2       7                 2
# 5361                   5            1       3                 1
# 7003                   8            0       2                 2
# 7416                   9            1       4                 0
# ...                  ...          ...     ...               ...
# 5734                   2            1       5                 2
# 5191                   3            1       5                 0
# 5390                   7            1       3                 0
# 860                    2            1       5                 0
# 7270                   1            0       1                 1
#
#       Sales Channel  Total Claim Amount  Vehicle Class  Vehicle Size
# 8607              0           57.712985              4             1
# 2121              0          960.399730              2             1
# 5361              1          456.503570              5             1
# 7003              3           94.338814              0             1
# 7416              1          650.521790              4             1
# ...             ...                 ...            ...           ...
# 5734              0          308.321335              0             2
# 5191              1          350.400000              0             1
# 5390              2          960.399730              3             1
# 860               2          667.200000              3             1
# 7270              1          344.015386              0             1
#
# [6850 rows x 23 columns]

# %%
# Create a first fitted model
lr = sm.OLS(y_train, X_train_lm).fit() # Ordinary Least Square

#lr.params

print(lr.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     84.15
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:03:53   Log-Likelihood:                -66076.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6827   BIC:                         1.324e+05
# Df Model:                               22
# Covariance Type:                 nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          1143.9905    347.899      3.288      0.001     462.000    1825.981
# State                           -18.6906     35.394     -0.528      0.597     -88.074      50.692
# Response                       -254.0699    133.770     -1.899      0.058    -516.302       8.162
# Coverage                       -130.9816     79.654     -1.644      0.100    -287.127      25.164
# Education                        81.4182     33.049      2.464      0.014      16.632     146.205
# Effective To Date                -1.4029      2.664     -0.527      0.599      -6.626       3.820
# EmploymentStatus                -95.6957     50.436     -1.897      0.058    -194.565       3.174
# Gender                          -23.3492     91.252     -0.256      0.798    -202.232     155.534
# Income                            0.0028      0.002      1.233      0.218      -0.002       0.007
# Location Code                   -61.3831     81.848     -0.750      0.453    -221.831      99.064
# Marital Status                 -103.3309     76.391     -1.353      0.176    -253.082      46.420
# Monthly Premium Auto             66.0742      2.333     28.318      0.000      61.500      70.648
# Months Since Last Claim           4.2618      4.498      0.948      0.343      -4.555      13.079
# Months Since Policy Inception    -1.0769      1.634     -0.659      0.510      -4.281       2.127
# Number of Open Complaints      -214.8861     49.679     -4.325      0.000    -312.273    -117.499
# Number of Policies              189.5853     18.955     10.002      0.000     152.428     226.743
# Policy Type                     254.3175    200.130      1.271      0.204    -137.999     646.634
# Policy                          -52.1363     59.352     -0.878      0.380    -168.485      64.212
# Renew Offer Type               -263.2684     47.010     -5.600      0.000    -355.422    -171.115
# Sales Channel                    -1.5424     42.973     -0.036      0.971     -85.784      82.699
# Total Claim Amount               -0.2624      0.292     -0.899      0.369      -0.835       0.310
# Vehicle Class                    14.1655     22.598      0.627      0.531     -30.134      58.465
# Vehicle Size                    124.8857     85.444      1.462      0.144     -42.611     292.383
# ==============================================================================
# Omnibus:                     1313.820   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2220.105
# Skew:                           1.284   Prob(JB):                         0.00
# Kurtosis:                       4.088   Cond. No.                     3.76e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.76e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Multicolinearity

# %%
vif_columns=X[['Income', 'Monthly Premium Auto', 'Months Since Last Claim', 'Months Since Policy Inception', 'Total Claim Amount']]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
#define a function to calculate VIF score
def vif_clac():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(vif_columns.values,i) for i in range(vif_columns.shape[1])]
    vif["features"]=vif_columns.columns
    print(vif)

# %%
#checking VIF score
vif_clac()
# Out:
#    VIF Factor                       features
# 0    2.832390                         Income
# 1   13.595632           Monthly Premium Auto
# 2    2.801431        Months Since Last Claim
# 3    3.331538  Months Since Policy Inception
# 4    7.435522             Total Claim Amount

# %%
# Drop high VIF score column
vif_columns=vif_columns.drop("Monthly Premium Auto",axis=1)

# %%
#checking VIF score
vif_clac()
# Out:
#    VIF Factor                       features
# 0    2.022801                         Income
# 1    2.632377        Months Since Last Claim
# 2    3.044310  Months Since Policy Inception
# 3    2.731842             Total Claim Amount

# %%
# now multicolinearity is under control

# %%
X_train_lm_1 = X_train_lm.drop(["Monthly Premium Auto"], axis=1)

lr_1 = sm.OLS(y_train, X_train_lm_1).fit()

#lr_1.params

print(lr_1.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.121
# Model:                                 OLS   Adj. R-squared:                  0.118
# Method:                      Least Squares   F-statistic:                     44.73
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):          5.14e-173
# Time:                             11:03:58   Log-Likelihood:                -66456.
# No. Observations:                     6850   AIC:                         1.330e+05
# Df Residuals:                         6828   BIC:                         1.331e+05
# Df Model:                               21
# Covariance Type:                 nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          5375.8433    332.082     16.188      0.000    4724.860    6026.827
# State                           -19.4533     37.412     -0.520      0.603     -92.793      53.886
# Response                       -454.8051    141.200     -3.221      0.001    -731.600    -178.010
# Coverage                        754.9621     77.429      9.750      0.000     603.177     906.747
# Education                        88.5286     34.933      2.534      0.011      20.050     157.007
# Effective To Date                -1.0854      2.816     -0.385      0.700      -6.606       4.435
# EmploymentStatus               -220.2154     53.109     -4.147      0.000    -324.325    -116.106
# Gender                         -126.8907     96.378     -1.317      0.188    -315.822      62.041
# Income                            0.0116      0.002      4.939      0.000       0.007       0.016
# Location Code                  -598.3426     84.161     -7.109      0.000    -763.325    -433.360
# Marital Status                 -276.9590     80.487     -3.441      0.001    -434.738    -119.180
# Months Since Last Claim           3.3525      4.754      0.705      0.481      -5.967      12.672
# Months Since Policy Inception     0.3961      1.727      0.229      0.819      -2.989       3.781
# Number of Open Complaints      -222.6723     52.511     -4.240      0.000    -325.611    -119.734
# Number of Policies              181.4765     20.034      9.059      0.000     142.205     220.748
# Policy Type                     211.0436    211.535      0.998      0.318    -203.631     625.718
# Policy                          -51.2431     62.736     -0.817      0.414    -174.226      71.740
# Renew Offer Type               -351.7526     49.580     -7.095      0.000    -448.945    -254.560
# Sales Channel                     7.8609     45.422      0.173      0.863     -81.181      96.903
# Total Claim Amount                4.6818      0.247     18.934      0.000       4.197       5.166
# Vehicle Class                   140.0646     23.420      5.981      0.000      94.154     185.975
# Vehicle Size                    -19.7087     90.155     -0.219      0.827    -196.440     157.023
# ==============================================================================
# Omnibus:                     1035.990   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1563.785
# Skew:                           1.144   Prob(JB):                         0.00
# Kurtosis:                       3.490   Cond. No.                     3.41e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.41e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     88.17
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:03:58   Log-Likelihood:                -66076.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6828   BIC:                         1.323e+05
# Df Model:                               21
# Covariance Type:                 nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          1142.2899    344.632      3.315      0.001     466.703    1817.877
# State                           -18.6872     35.391     -0.528      0.598     -88.065      50.690
# Response                       -253.7169    133.399     -1.902      0.057    -515.220       7.786
# Coverage                       -130.8814     79.599     -1.644      0.100    -286.920      25.157
# Education                        81.4359     33.043      2.465      0.014      16.661     146.210
# Effective To Date                -1.4011      2.664     -0.526      0.599      -6.623       3.821
# EmploymentStatus                -95.7044     50.431     -1.898      0.058    -194.566       3.157
# Gender                          -23.2559     91.209     -0.255      0.799    -202.054     155.542
# Income                            0.0028      0.002      1.233      0.218      -0.002       0.007
# Location Code                   -61.3481     81.836     -0.750      0.453    -221.772      99.076
# Marital Status                 -103.2677     76.365     -1.352      0.176    -252.968      46.432
# Monthly Premium Auto             66.0736      2.333     28.320      0.000      61.500      70.647
# Months Since Last Claim           4.2613      4.497      0.947      0.343      -4.555      13.078
# Months Since Policy Inception    -1.0776      1.634     -0.659      0.510      -4.281       2.126
# Number of Open Complaints      -214.8945     49.675     -4.326      0.000    -312.274    -117.516
# Number of Policies              189.5692     18.948     10.005      0.000     152.425     226.714
# Policy Type                     254.3278    200.115      1.271      0.204    -137.959     646.615
# Policy                          -52.1333     59.348     -0.878      0.380    -168.473      64.207
# Renew Offer Type               -263.4673     46.678     -5.644      0.000    -354.972    -171.963
# Total Claim Amount               -0.2625      0.292     -0.899      0.368      -0.835       0.310
# Vehicle Class                    14.1611     22.596      0.627      0.531     -30.135      58.457
# Vehicle Size                    124.9392     85.425      1.463      0.144     -42.520     292.398
# ==============================================================================
# Omnibus:                     1313.826   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2220.122
# Skew:                           1.284   Prob(JB):                         0.00
# Kurtosis:                       4.088   Cond. No.                     3.73e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.73e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     92.46
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:03:58   Log-Likelihood:                -66077.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6829   BIC:                         1.323e+05
# Df Model:                               20
# Covariance Type:                 nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          1281.8136    331.194      3.870      0.000     632.571    1931.057
# State                           -18.7234     35.394     -0.529      0.597     -88.107      50.660
# Response                       -264.5064    133.206     -1.986      0.047    -525.631      -3.382
# Coverage                       -131.2381     79.605     -1.649      0.099    -287.289      24.813
# Education                        80.6089     33.041      2.440      0.015      15.839     145.379
# Effective To Date                -1.4560      2.664     -0.547      0.585      -6.678       3.766
# EmploymentStatus                -96.8875     50.429     -1.921      0.055    -195.744       1.969
# Gender                          -24.7678     91.211     -0.272      0.786    -203.569     154.033
# Income                            0.0029      0.002      1.283      0.200      -0.002       0.007
# Location Code                   -64.8222     81.808     -0.792      0.428    -225.192      95.548
# Marital Status                 -103.2282     76.372     -1.352      0.177    -252.941      46.484
# Monthly Premium Auto             65.8691      2.329     28.281      0.000      61.303      70.435
# Months Since Last Claim           4.2230      4.498      0.939      0.348      -4.594      13.040
# Months Since Policy Inception    -1.0587      1.634     -0.648      0.517      -4.262       2.145
# Number of Open Complaints      -214.9430     49.679     -4.327      0.000    -312.330    -117.556
# Number of Policies              190.2154     18.945     10.041      0.000     153.078     227.353
# Policy Type                     259.5479    200.100      1.297      0.195    -132.710     651.805
# Policy                          -53.2853     59.347     -0.898      0.369    -169.625      63.054
# Renew Offer Type               -263.0753     46.682     -5.636      0.000    -354.586    -171.565
# Total Claim Amount               -0.2133      0.290     -0.736      0.462      -0.782       0.355
# Vehicle Class                    13.4093     22.592      0.594      0.553     -30.879      57.697
# ==============================================================================
# Omnibus:                     1313.920   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2220.391
# Skew:                           1.284   Prob(JB):                         0.00
# Kurtosis:                       4.088   Cond. No.                     3.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     97.33
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:03:59   Log-Likelihood:                -66077.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6830   BIC:                         1.323e+05
# Df Model:                               19
# Covariance Type:                 nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          1272.1801    329.266      3.864      0.000     626.716    1917.644
# State                           -18.5975     35.389     -0.526      0.599     -87.970      50.775
# Response                       -264.7870    133.193     -1.988      0.047    -525.886      -3.688
# Coverage                       -130.9918     79.594     -1.646      0.100    -287.022      25.038
# Education                        80.6664     33.038      2.442      0.015      15.902     145.431
# Effective To Date                -1.4531      2.663     -0.546      0.585      -6.674       3.768
# EmploymentStatus                -97.0515     50.422     -1.925      0.054    -195.894       1.792
# Income                            0.0029      0.002      1.275      0.202      -0.002       0.007
# Location Code                   -64.2497     81.776     -0.786      0.432    -224.556      96.056
# Marital Status                 -103.7078     76.346     -1.358      0.174    -253.370      45.954
# Monthly Premium Auto             65.8943      2.327     28.316      0.000      61.332      70.456
# Months Since Last Claim           4.1846      4.495      0.931      0.352      -4.628      12.997
# Months Since Policy Inception    -1.0654      1.634     -0.652      0.514      -4.268       2.137
# Number of Open Complaints      -214.9560     49.676     -4.327      0.000    -312.336    -117.576
# Number of Policies              190.1339     18.941     10.038      0.000     153.003     227.264
# Policy Type                     259.9215    200.081      1.299      0.194    -132.300     652.143
# Policy                          -53.2873     59.343     -0.898      0.369    -169.619      63.044
# Renew Offer Type               -263.6490     46.631     -5.654      0.000    -355.060    -172.238
# Total Claim Amount               -0.2201      0.289     -0.762      0.446      -0.786       0.346
# Vehicle Class                    13.3455     22.589      0.591      0.555     -30.937      57.628
# ==============================================================================
# Omnibus:                     1314.185   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2221.121
# Skew:                           1.284   Prob(JB):                         0.00
# Kurtosis:                       4.089   Cond. No.                     3.56e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.56e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     102.7
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:03:59   Log-Likelihood:                -66077.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6831   BIC:                         1.323e+05
# Df Model:                               18
# Covariance Type:                 nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          1241.6144    324.071      3.831      0.000     606.334    1876.894
# Response                       -264.8656    133.185     -1.989      0.047    -525.950      -3.781
# Coverage                       -131.1323     79.590     -1.648      0.099    -287.153      24.888
# Education                        80.3167     33.029      2.432      0.015      15.569     145.065
# Effective To Date                -1.4538      2.663     -0.546      0.585      -6.675       3.767
# EmploymentStatus                -97.1150     50.419     -1.926      0.054    -195.952       1.723
# Income                            0.0029      0.002      1.270      0.204      -0.002       0.007
# Location Code                   -63.9502     81.769     -0.782      0.434    -224.244      96.343
# Marital Status                 -104.5800     76.324     -1.370      0.171    -254.199      45.039
# Monthly Premium Auto             65.8945      2.327     28.318      0.000      61.333      70.456
# Months Since Last Claim           4.2067      4.495      0.936      0.349      -4.605      13.018
# Months Since Policy Inception    -1.0710      1.634     -0.656      0.512      -4.274       2.132
# Number of Open Complaints      -215.0064     49.673     -4.328      0.000    -312.381    -117.631
# Number of Policies              190.2648     18.938     10.046      0.000     153.140     227.390
# Policy Type                     260.0595    200.071      1.300      0.194    -132.141     652.260
# Policy                          -53.4215     59.340     -0.900      0.368    -169.746      62.903
# Renew Offer Type               -263.4755     46.627     -5.651      0.000    -354.879    -172.072
# Total Claim Amount               -0.2198      0.289     -0.761      0.447      -0.786       0.346
# Vehicle Class                    13.1942     22.586      0.584      0.559     -31.082      57.471
# ==============================================================================
# Omnibus:                     1313.613   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2219.512
# Skew:                           1.284   Prob(JB):                         0.00
# Kurtosis:                       4.088   Cond. No.                     3.50e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.5e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     108.8
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:03:59   Log-Likelihood:                -66077.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6832   BIC:                         1.323e+05
# Df Model:                               17
# Covariance Type:                 nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          1193.8006    311.992      3.826      0.000     582.200    1805.401
# Response                       -262.1902    133.088     -1.970      0.049    -523.085      -1.296
# Coverage                       -130.2767     79.570     -1.637      0.102    -286.259      25.706
# Education                        80.5029     33.026      2.438      0.015      15.762     145.244
# EmploymentStatus                -96.8993     50.415     -1.922      0.055    -195.729       1.930
# Income                            0.0029      0.002      1.274      0.203      -0.002       0.007
# Location Code                   -62.8677     81.741     -0.769      0.442    -223.106      97.370
# Marital Status                 -104.1454     76.316     -1.365      0.172    -253.749      45.458
# Monthly Premium Auto             65.8881      2.327     28.317      0.000      61.327      70.449
# Months Since Last Claim           4.2539      4.494      0.947      0.344      -4.555      13.063
# Months Since Policy Inception    -1.0795      1.634     -0.661      0.509      -4.282       2.123
# Number of Open Complaints      -214.2695     49.652     -4.315      0.000    -311.604    -116.935
# Number of Policies              190.2800     18.937     10.048      0.000     153.157     227.403
# Policy Type                     260.5431    200.058      1.302      0.193    -131.633     652.720
# Policy                          -53.2017     59.335     -0.897      0.370    -169.517      63.114
# Renew Offer Type               -263.1652     46.621     -5.645      0.000    -354.557    -171.773
# Total Claim Amount               -0.2185      0.289     -0.756      0.449      -0.785       0.348
# Vehicle Class                    13.4399     22.581      0.595      0.552     -30.826      57.705
# ==============================================================================
# Omnibus:                     1313.782   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2219.934
# Skew:                           1.284   Prob(JB):                         0.00
# Kurtosis:                       4.088   Cond. No.                     3.38e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.38e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     115.6
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:03:59   Log-Likelihood:                -66077.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6833   BIC:                         1.323e+05
# Df Model:                               16
# Covariance Type:                 nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                          1196.2988    311.949      3.835      0.000     584.783    1807.815
# Response                       -260.0925    133.035     -1.955      0.051    -520.883       0.698
# Coverage                       -136.6520     78.842     -1.733      0.083    -291.207      17.903
# Education                        80.7495     33.022      2.445      0.014      16.016     145.483
# EmploymentStatus                -97.0136     50.412     -1.924      0.054    -195.838       1.810
# Income                            0.0029      0.002      1.278      0.201      -0.002       0.007
# Location Code                   -62.6274     81.736     -0.766      0.444    -222.856      97.601
# Marital Status                 -103.3058     76.299     -1.354      0.176    -252.876      46.265
# Monthly Premium Auto             66.1627      2.281     29.012      0.000      61.692      70.633
# Months Since Last Claim           4.2395      4.493      0.943      0.345      -4.569      13.048
# Months Since Policy Inception    -1.0883      1.633     -0.666      0.505      -4.290       2.114
# Number of Open Complaints      -214.3742     49.650     -4.318      0.000    -311.703    -117.045
# Number of Policies              190.2703     18.937     10.048      0.000     153.149     227.392
# Policy Type                     259.1285    200.035      1.295      0.195    -133.002     651.259
# Policy                          -52.7969     59.329     -0.890      0.374    -169.099      63.505
# Renew Offer Type               -263.5336     46.615     -5.653      0.000    -354.913    -172.154
# Total Claim Amount               -0.2194      0.289     -0.760      0.448      -0.785       0.347
# ==============================================================================
# Omnibus:                     1315.387   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2224.076
# Skew:                           1.285   Prob(JB):                         0.00
# Kurtosis:                       4.090   Cond. No.                     3.38e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.38e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     123.2
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:03:59   Log-Likelihood:                -66078.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6834   BIC:                         1.323e+05
# Df Model:                               15
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1142.5976    301.345      3.792      0.000     551.869    1733.327
# Response                   -259.4208    133.026     -1.950      0.051    -520.193       1.352
# Coverage                   -136.3680     78.838     -1.730      0.084    -290.915      18.179
# Education                    80.4663     33.018      2.437      0.015      15.741     145.191
# EmploymentStatus            -98.0955     50.384     -1.947      0.052    -196.864       0.673
# Income                        0.0028      0.002      1.267      0.205      -0.002       0.007
# Location Code               -63.2398     81.728     -0.774      0.439    -223.452      96.972
# Marital Status             -102.1752     76.277     -1.340      0.180    -251.703      47.352
# Monthly Premium Auto         66.1174      2.279     29.006      0.000      61.649      70.586
# Months Since Last Claim       4.3651      4.489      0.972      0.331      -4.435      13.166
# Number of Open Complaints  -214.1291     49.646     -4.313      0.000    -311.451    -116.807
# Number of Policies          190.4370     18.934     10.058      0.000     153.320     227.554
# Policy Type                 260.8107    200.011      1.304      0.192    -131.272     652.894
# Policy                      -53.0173     59.325     -0.894      0.372    -169.313      63.279
# Renew Offer Type           -260.8346     46.437     -5.617      0.000    -351.865    -169.804
# Total Claim Amount           -0.2135      0.289     -0.740      0.460      -0.779       0.352
# ==============================================================================
# Omnibus:                     1315.300   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2223.773
# Skew:                           1.285   Prob(JB):                         0.00
# Kurtosis:                       4.089   Cond. No.                     3.27e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.27e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     132.0
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:00   Log-Likelihood:                -66078.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6835   BIC:                         1.323e+05
# Df Model:                               14
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1176.3686    297.856      3.949      0.000     592.478    1760.259
# Response                   -265.7621    132.745     -2.002      0.045    -525.984      -5.540
# Coverage                   -136.7293     78.834     -1.734      0.083    -291.268      17.809
# Education                    79.9932     33.010      2.423      0.015      15.282     144.704
# EmploymentStatus           -103.0767     49.930     -2.064      0.039    -200.956      -5.197
# Income                        0.0033      0.002      1.500      0.134      -0.001       0.008
# Location Code               -87.4603     74.879     -1.168      0.243    -234.246      59.326
# Marital Status             -110.6339     75.413     -1.467      0.142    -258.466      37.199
# Monthly Premium Auto         65.0952      1.813     35.912      0.000      61.542      68.648
# Months Since Last Claim       4.3788      4.489      0.975      0.329      -4.421      13.179
# Number of Open Complaints  -214.1141     49.645     -4.313      0.000    -311.433    -116.795
# Number of Policies          190.3023     18.933     10.052      0.000     153.188     227.416
# Policy Type                 258.4264    199.978      1.292      0.196    -133.593     650.446
# Policy                      -52.5822     59.320     -0.886      0.375    -168.868      63.704
# Renew Offer Type           -261.5132     46.426     -5.633      0.000    -352.523    -170.504
# ==============================================================================
# Omnibus:                     1315.328   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2223.815
# Skew:                           1.285   Prob(JB):                         0.00
# Kurtosis:                       4.089   Cond. No.                     3.23e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.23e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount", "Policy"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     142.1
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:00   Log-Likelihood:                -66078.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6836   BIC:                         1.323e+05
# Df Model:                               13
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1105.8158    287.020      3.853      0.000     543.168    1668.464
# Response                   -265.3008    132.742     -1.999      0.046    -525.517      -5.085
# Coverage                   -135.9534     78.828     -1.725      0.085    -290.480      18.573
# Education                    79.9645     33.010      2.422      0.015      15.255     144.674
# EmploymentStatus           -104.2469     49.912     -2.089      0.037    -202.090      -6.403
# Income                        0.0032      0.002      1.479      0.139      -0.001       0.007
# Location Code               -86.9020     74.875     -1.161      0.246    -233.680      59.876
# Marital Status             -109.7963     75.406     -1.456      0.145    -257.615      38.022
# Monthly Premium Auto         65.0997      1.813     35.915      0.000      61.546      68.653
# Months Since Last Claim       4.3972      4.489      0.980      0.327      -4.403      13.197
# Number of Open Complaints  -214.3480     49.643     -4.318      0.000    -311.664    -117.032
# Number of Policies          190.5189     18.931     10.064      0.000     153.409     227.629
# Policy Type                 102.5925     95.311      1.076      0.282     -84.247     289.432
# Renew Offer Type           -261.0833     46.423     -5.624      0.000    -352.086    -170.080
# ==============================================================================
# Omnibus:                     1314.944   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2222.678
# Skew:                           1.285   Prob(JB):                         0.00
# Kurtosis:                       4.088   Cond. No.                     3.11e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.11e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount", "Policy", "Months Since Last Claim"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     153.9
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:00   Log-Likelihood:                -66079.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6837   BIC:                         1.323e+05
# Df Model:                               12
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1178.5185    277.256      4.251      0.000     635.010    1722.027
# Response                   -268.4954    132.702     -2.023      0.043    -528.632      -8.359
# Coverage                   -134.0482     78.803     -1.701      0.089    -288.527      20.431
# Education                    80.3164     33.008      2.433      0.015      15.611     145.022
# EmploymentStatus           -104.9721     49.907     -2.103      0.035    -202.805      -7.140
# Income                        0.0032      0.002      1.458      0.145      -0.001       0.007
# Location Code               -87.7430     74.870     -1.172      0.241    -234.511      59.025
# Marital Status             -108.9840     75.401     -1.445      0.148    -256.793      38.825
# Monthly Premium Auto         65.0703      1.812     35.904      0.000      61.518      68.623
# Number of Open Complaints  -214.6322     49.642     -4.324      0.000    -311.946    -117.318
# Number of Policies          190.4959     18.931     10.063      0.000     153.386     227.606
# Policy Type                 101.1268     95.299      1.061      0.289     -85.689     287.942
# Renew Offer Type           -261.4060     46.421     -5.631      0.000    -352.406    -170.406
# ==============================================================================
# Omnibus:                     1316.458   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2226.623
# Skew:                           1.286   Prob(JB):                         0.00
# Kurtosis:                       4.090   Cond. No.                     3.01e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.01e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount", "Policy", "Months Since Last Claim", "Policy Type"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.213
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     167.8
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:00   Log-Likelihood:                -66079.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6838   BIC:                         1.323e+05
# Df Model:                               11
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1263.9459    265.314      4.764      0.000     743.848    1784.044
# Response                   -267.9753    132.702     -2.019      0.043    -528.112      -7.838
# Coverage                   -133.9869     78.804     -1.700      0.089    -288.468      20.494
# Education                    80.3401     33.008      2.434      0.015      15.634     145.046
# EmploymentStatus           -105.9033     49.899     -2.122      0.034    -203.722      -8.085
# Income                        0.0032      0.002      1.454      0.146      -0.001       0.007
# Location Code               -86.7561     74.865     -1.159      0.247    -233.515      60.002
# Marital Status             -107.3110     75.385     -1.424      0.155    -255.089      40.467
# Monthly Premium Auto         65.0524      1.812     35.896      0.000      61.500      68.605
# Number of Open Complaints  -213.8925     49.638     -4.309      0.000    -311.198    -116.587
# Number of Policies          190.1779     18.928     10.047      0.000     153.072     227.284
# Renew Offer Type           -261.5470     46.422     -5.634      0.000    -352.548    -170.546
# ==============================================================================
# Omnibus:                     1317.414   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2228.983
# Skew:                           1.287   Prob(JB):                         0.00
# Kurtosis:                       4.090   Cond. No.                     2.88e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount", "Policy", "Months Since Last Claim", "Policy Type", "Location Code"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.212
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     184.4
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:01   Log-Likelihood:                -66080.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6839   BIC:                         1.323e+05
# Df Model:                               10
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1177.4667    254.609      4.625      0.000     678.354    1676.579
# Response                   -268.1330    132.705     -2.021      0.043    -528.276      -7.990
# Coverage                   -131.2682     78.771     -1.666      0.096    -285.684      23.148
# Education                    80.6278     33.008      2.443      0.015      15.922     145.334
# EmploymentStatus           -105.3229     49.898     -2.111      0.035    -203.139      -7.507
# Income                        0.0032      0.002      1.481      0.139      -0.001       0.007
# Marital Status             -108.9606     75.374     -1.446      0.148    -256.716      38.795
# Monthly Premium Auto         65.0249      1.812     35.883      0.000      61.473      68.577
# Number of Open Complaints  -213.6126     49.638     -4.303      0.000    -310.919    -116.306
# Number of Policies          189.9624     18.928     10.036      0.000     152.858     227.067
# Renew Offer Type           -260.4448     46.413     -5.611      0.000    -351.429    -169.461
# ==============================================================================
# Omnibus:                     1318.345   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2231.443
# Skew:                           1.287   Prob(JB):                         0.00
# Kurtosis:                       4.092   Cond. No.                     2.76e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.76e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount", "Policy", "Months Since Last Claim", "Policy Type", "Location Code", "Marital Status"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.212
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     204.6
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:01   Log-Likelihood:                -66081.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6840   BIC:                         1.323e+05
# Df Model:                                9
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1086.3220    246.699      4.403      0.000     602.716    1569.928
# Response                   -249.8181    132.110     -1.891      0.059    -508.794       9.158
# Coverage                   -131.9628     78.776     -1.675      0.094    -286.388      22.463
# Education                    79.8675     33.007      2.420      0.016      15.164     144.571
# EmploymentStatus           -120.7589     48.746     -2.477      0.013    -216.316     -25.202
# Income                        0.0032      0.002      1.494      0.135      -0.001       0.007
# Monthly Premium Auto         64.9900      1.812     35.864      0.000      61.438      68.542
# Number of Open Complaints  -213.5550     49.642     -4.302      0.000    -310.869    -116.241
# Number of Policies          189.4412     18.926     10.010      0.000     152.340     226.542
# Renew Offer Type           -260.2211     46.417     -5.606      0.000    -351.212    -169.230
# ==============================================================================
# Omnibus:                     1317.458   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2228.984
# Skew:                           1.287   Prob(JB):                         0.00
# Kurtosis:                       4.090   Cond. No.                     2.67e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.67e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount", "Policy", "Months Since Last Claim", "Policy Type", "Location Code", "Marital Status", "Income"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.212
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     229.9
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:01   Log-Likelihood:                -66082.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6841   BIC:                         1.322e+05
# Df Model:                                8
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1301.2089    200.470      6.491      0.000     908.226    1694.192
# Response                   -247.1204    132.109     -1.871      0.061    -506.095      11.855
# Coverage                   -131.7870     78.783     -1.673      0.094    -286.226      22.652
# Education                    79.3335     33.008      2.403      0.016      14.628     144.039
# EmploymentStatus           -172.9720     33.993     -5.089      0.000    -239.608    -106.336
# Monthly Premium Auto         64.9517      1.812     35.843      0.000      61.399      68.504
# Number of Open Complaints  -211.4635     49.627     -4.261      0.000    -308.748    -114.179
# Number of Policies          189.4783     18.928     10.011      0.000     152.374     226.583
# Renew Offer Type           -255.0874     46.293     -5.510      0.000    -345.837    -164.338
# ==============================================================================
# Omnibus:                     1316.244   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2225.693
# Skew:                           1.286   Prob(JB):                         0.00
# Kurtosis:                       4.087   Cond. No.                         435.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount", "Policy", "Months Since Last Claim", "Policy Type", "Location Code", "Marital Status", "Income", "Coverage"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.212
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     262.3
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:01   Log-Likelihood:                -66084.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6842   BIC:                         1.322e+05
# Df Model:                                7
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1369.1213    196.341      6.973      0.000     984.231    1754.011
# Response                   -246.7538    132.126     -1.868      0.062    -505.762      12.255
# Education                    79.2769     33.012      2.401      0.016      14.563     143.990
# EmploymentStatus           -172.8939     33.997     -5.086      0.000    -239.539    -106.249
# Monthly Premium Auto         63.4944      1.589     39.955      0.000      60.379      66.610
# Number of Open Complaints  -210.3733     49.629     -4.239      0.000    -307.662    -113.084
# Number of Policies          189.8543     18.929     10.030      0.000     152.748     226.961
# Renew Offer Type           -254.3304     46.297     -5.493      0.000    -345.087    -163.573
# ==============================================================================
# Omnibus:                     1316.823   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2227.314
# Skew:                           1.286   Prob(JB):                         0.00
# Kurtosis:                       4.089   Cond. No.                         425.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train_lm_2 = X_train_lm.drop(["Sales Channel","Vehicle Size", "Gender", "State", "Effective To Date", "Vehicle Class", "Months Since Policy Inception", "Total Claim Amount", "Policy", "Months Since Last Claim", "Policy Type", "Location Code", "Marital Status", "Income", "Coverage", "Response"], axis=1)

lr_2 = sm.OLS(y_train, X_train_lm_2).fit()

#lr_2.params

print(lr_2.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Customer Lifetime Value   R-squared:                       0.211
# Model:                                 OLS   Adj. R-squared:                  0.210
# Method:                      Least Squares   F-statistic:                     305.3
# Date:                     Tue, 21 Nov 2023   Prob (F-statistic):               0.00
# Time:                             11:04:02   Log-Likelihood:                -66085.
# No. Observations:                     6850   AIC:                         1.322e+05
# Df Residuals:                         6843   BIC:                         1.322e+05
# Df Model:                                6
# Covariance Type:                 nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1306.1574    193.460      6.752      0.000     926.915    1685.400
# Education                    79.7616     33.017      2.416      0.016      15.038     144.485
# EmploymentStatus           -170.5928     33.981     -5.020      0.000    -237.206    -103.980
# Monthly Premium Auto         63.5351      1.589     39.977      0.000      60.420      66.651
# Number of Open Complaints  -208.3432     49.626     -4.198      0.000    -305.626    -111.060
# Number of Policies          191.3558     18.915     10.116      0.000     154.276     228.436
# Renew Offer Type           -239.6365     45.632     -5.251      0.000    -329.090    -150.183
# ==============================================================================
# Omnibus:                     1312.243   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2214.985
# Skew:                           1.284   Prob(JB):                         0.00
# Kurtosis:                       4.080   Cond. No.                         414.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Applying Supervised Regression Models

# %%
X = df_no_outliers.drop(['Customer Lifetime Value'], axis=1) # Data set of all independet variables

y = df_no_outliers['Customer Lifetime Value'] # Dataset of target variable

# %%
# Remove skewness:

# %%
#checking skewness
X.skew()
# Out:
# State                            0.210423
# Response                         2.037567
# Coverage                         1.031310
# Education                        0.333148
# Effective To Date                0.026394
# EmploymentStatus                 0.832147
# Gender                           0.039866
# Income                           0.286887
# Location Code                    0.009511
# Marital Status                  -0.107553
# Monthly Premium Auto             1.139909
# Months Since Last Claim          0.278586
# Months Since Policy Inception    0.040165
# Number of Open Complaints        2.783263
# Number of Policies               1.253333
# Policy Type                     -0.468383
# Policy                          -0.427639
# Renew Offer Type                 0.717398
# Sales Channel                    0.506774
# Total Claim Amount               0.515674
# Vehicle Class                    0.395146
# Vehicle Size                     0.072742
# dtype: float64

# %%
#we use power transformation(method= yeo-johnson) method to remove skewness of the columns
from sklearn.preprocessing import power_transform
X=power_transform(X,method='yeo-johnson')
X
# Out:
# array([[ 1.54929746, -0.40882171, -0.79595349, ..., -0.01628177,
#          1.25165048, -0.16135295],
#        [-1.52276618, -0.40882171,  1.15172433, ...,  1.93427632,
#         -0.96781268, -0.16135295],
#        [ 0.32268076, -0.40882171,  1.54592345, ...,  0.67467618,
#          1.25165048, -0.16135295],
#        ...,
#        [-0.46741186, -0.40882171,  1.15172433, ...,  1.4215024 ,
#         -0.96781268, -0.16135295],
#        [-0.46741186, -0.40882171,  1.15172433, ...,  1.10125662,
#         -0.96781268, -2.04589801],
#        [-0.46741186, -0.40882171,  1.15172433, ..., -0.07915715,
#          1.25165048, -0.16135295]])

# %%
#print skewness after power transform
df_new1=pd.DataFrame(X,columns=df_no_outliers.drop("Customer Lifetime Value",axis=1).columns)
df_new1.skew()
# Out:
# State                           -0.098778
# Response                         2.037567
# Coverage                         0.484596
# Education                       -0.045143
# Effective To Date               -0.251711
# EmploymentStatus                 0.019955
# Gender                           0.039866
# Income                          -0.856134
# Location Code                   -0.047444
# Marital Status                  -0.075707
# Monthly Premium Auto             0.156473
# Months Since Last Claim         -0.181582
# Months Since Policy Inception   -0.251611
# Number of Open Complaints        1.455797
# Number of Policies               0.199297
# Policy Type                      0.039913
# Policy                          -0.078825
# Renew Offer Type                 0.070461
# Sales Channel                    0.015371
# Total Claim Amount              -0.098768
# Vehicle Class                    0.127872
# Vehicle Size                     0.033699
# dtype: float64

# %%
df_new1.shape
# Out:
# (9134, 22)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the number of rows and columns for the subplot grid
n_rows = 4  # You can adjust the number of rows and columns as needed
n_cols = 6

# Create subplots
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(16, 12))
plt.subplots_adjust(wspace=0.5, hspace=0.5)  # Adjust the spacing between subplots

# Iterate through the columns and create distribution plots
for i, column_name in enumerate(df_new1.columns):
    row_index = i // n_cols  # Calculate the row index
    col_index = i % n_cols   # Calculate the column index

    # Create the distribution plot in the appropriate subplot
    sns.distplot(df_new1[column_name], ax=axes[row_index, col_index])
    axes[row_index, col_index].set_title(f'Distribution of {column_name}')

# Hide any empty subplots
for i in range(len(df_new1.columns), n_rows * n_cols):
    row_index = i // n_cols
    col_index = i % n_cols
    fig.delaxes(axes[row_index, col_index])

# Display the subplots
plt.show()

# %%
#standardizing the data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)
X
# Out:
# array([[ 1.54929746, -0.40882171, -0.79595349, ..., -0.01628177,
#          1.25165048, -0.16135295],
#        [-1.52276618, -0.40882171,  1.15172433, ...,  1.93427632,
#         -0.96781268, -0.16135295],
#        [ 0.32268076, -0.40882171,  1.54592345, ...,  0.67467618,
#          1.25165048, -0.16135295],
#        ...,
#        [-0.46741186, -0.40882171,  1.15172433, ...,  1.4215024 ,
#         -0.96781268, -0.16135295],
#        [-0.46741186, -0.40882171,  1.15172433, ...,  1.10125662,
#         -0.96781268, -2.04589801],
#        [-0.46741186, -0.40882171,  1.15172433, ..., -0.07915715,
#          1.25165048, -0.16135295]])

# %%
train_x,test_x,train_y,test_y=train_test_split(X,y,test_size=.25,random_state=42)

# %%
#cheking shape of all variable
print("train_x shape =",train_x.shape)
print("test_x shape =",test_x.shape)
print("train_y shape =",train_y.shape)
print("test_y shape =",test_y.shape)
# Out:
# train_x shape = (6850, 22)
# test_x shape = (2284, 22)
# train_y shape = (6850,)
# test_y shape = (2284,)

# %%
lm=LinearRegression()
lm.fit(train_x,train_y)
lm.score(train_x,train_y)
# Out:
# 0.2831508964278411

# %%
lm.coef_
# Out:
# array([ 8.87954327e-01, -5.78367750e+01, -2.17587666e+02,  8.94614985e+01,
#        -3.98907468e+01, -3.04438150e+00, -2.96137564e+01,  2.63717961e+02,
#        -1.26135310e+02, -8.23794826e+01,  1.79067666e+03,  5.43270440e+01,
#        -6.63281962e+00, -1.09570193e+02,  1.30971600e+03,  8.91497642e+01,
#        -5.36058239e+01, -1.69781226e+02, -5.33255680e+00,  1.45462250e+02,
#         2.47738985e+01,  3.53223700e+01])

# %%
lm.intercept_
# Out:
# 7183.688914203036

# %%
# Error of Llinear regression Model

from sklearn.metrics import mean_absolute_error,mean_squared_error
predlm=lm.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))
# Out:
# Mean Absolute Error:  2820.711030518328
# Mean Squared Error:  13107230.320243655
# Root Mean Squared Error:  3620.3909071043217

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[84], line 7
#       5 from sklearn.neighbors import KNeighborsRegressor
#       6 from sklearn.ensemble import RandomForestRegressor
# ----> 7 from xgboost import XGBRegressor
#       8 from sklearn.ensemble import AdaBoostRegressor
#       9 from sklearn.ensemble import GradientBoostingRegressor
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
LR_model= LinearRegression()
RD_model= Ridge()
LS_model= Lasso()
DT_model= DecisionTreeRegressor()
SV_model= SVR()
KNR_model= KNeighborsRegressor()
RFR_model= RandomForestRegressor()
XGB_model= XGBRegressor()
ADA_model=AdaBoostRegressor()
GB_model= GradientBoostingRegressor()

# %%
model=[LR_model,RD_model,LS_model,DT_model,SV_model,KNR_model,RFR_model,XGB_model,ADA_model,GB_model]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# List of models
models = [LR_model, RD_model, LS_model, DT_model, SV_model, KNR_model, RFR_model, XGB_model, ADA_model, GB_model]

# Loop through the models and calculate/print metrics
for model in models:
    model.fit(train_x, train_y)  # Fit the model with training data
    pred = model.predict(test_x)
    
    mae = mean_absolute_error(test_y, pred)
    mse = mean_squared_error(test_y, pred)
    rmse = np.sqrt(mse)
    
    print(f'Model: {model.__class__.__name__}')
    print('Mean Absolute Error: ', mae)
    print('Mean Squared Error: ', mse)
    print('Root Mean Squared Error: ', rmse)
    print()

# %%
#we get best accuracy from RandomForestRegressor and XGBRegressor

# %% [markdown]
# # Parameter Tuning for RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in GreadSearchCV
param_grid = {
    'n_estimators': [50, 100, 150, 200],
    'max_depth': [None, 10, 20, 30, 40],
}
gcv1=GridSearchCV(RandomForestRegressor(),param_grid,cv=5,scoring='neg_mean_squared_error')
gcv1.fit(train_x,train_y)
gcv1.best_params_

# %%
best_estimator = gcv1.best_estimator_
best_estimator

# %%
print('ERROR:')
from sklearn.metrics import mean_absolute_error,mean_squared_error
predlm=best_estimator.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))

# %%
output_df= pd.DataFrame({'Original':test_y, 'Predicted':predlm},columns=["Predicted","Original"])
sns.lmplot(x='Original',y='Predicted',data=output_df,palette='rainbow')

# %% [markdown]
# # Parameter Tuning for LinearRegression

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in GreadSearchCV
param_grid = {
    'fit_intercept': [True, False],
    'normalize': [True, False],
    'copy_X': [True, False],
    'n_jobs': [None, -1],  # -1 means to use all available CPU cores
}
gcv1=GridSearchCV(LinearRegression(),param_grid,cv=5,scoring='neg_mean_squared_error')
gcv1.fit(train_x,train_y)
gcv1.best_params_

# %%
print('ERROR:')
from sklearn.metrics import mean_absolute_error,mean_squared_error
best_estimator = gcv1.best_estimator_
best_estimator
predlm=best_estimator.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))

# %%
output_df= pd.DataFrame({'Original':test_y, 'Predicted':predlm},columns=["Predicted","Original"])
sns.lmplot(x='Original',y='Predicted',data=output_df,palette='rainbow')

# %% [markdown]
# # Parameter Tuning for Ridge

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in GreadSearchCV
param_grid = {
    'alpha': [0.001, 0.01, 0.1, 1, 10, 100],  # List of alpha values to search
    'normalize': [True, False]  # True or False for feature normalization
}
gcv1=GridSearchCV(Ridge(),param_grid,cv=5,scoring='neg_mean_squared_error')
gcv1.fit(train_x,train_y)
gcv1.best_params_

# %%
print('ERROR:')
from sklearn.metrics import mean_absolute_error,mean_squared_error
best_estimator = gcv1.best_estimator_
best_estimator
predlm=best_estimator.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))

# %%
output_df= pd.DataFrame({'Original':test_y, 'Predicted':predlm},columns=["Predicted","Original"])
sns.lmplot(x='Original',y='Predicted',data=output_df,palette='rainbow')

# %% [markdown]
# # Parameter Tuning for Lasso

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in GreadSearchCV
param_grid = {
    'alpha': [0.001, 0.01, 0.1, 1.0, 10.0],  # Range of alpha values to test
    'fit_intercept': [True, False],          # Whether to fit an intercept term
    'normalize': [True, False],             # Whether to normalize the features
}
gcv1=GridSearchCV(Lasso(),param_grid,cv=5,scoring='neg_mean_squared_error')
gcv1.fit(train_x,train_y)
gcv1.best_params_

# %%
print('ERROR:')
from sklearn.metrics import mean_absolute_error,mean_squared_error
best_estimator = gcv1.best_estimator_
best_estimator
predlm=best_estimator.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))

# %%
output_df= pd.DataFrame({'Original':test_y, 'Predicted':predlm},columns=["Predicted","Original"])
sns.lmplot(x='Original',y='Predicted',data=output_df,palette='rainbow')

# %% [markdown]
# # Parameter Tuning for DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in GreadSearchCV
param_grid = {
    'criterion': ['mse', 'mae'],  # Splitting criterion: Mean Squared Error (MSE) or Mean Absolute Error (MAE)
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # Minimum samples required to be a leaf node
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider when splitting
    'random_state': [42]  # Set a specific random seed for reproducibility
}
gcv1=GridSearchCV(DecisionTreeRegressor(),param_grid,cv=5,scoring='neg_mean_squared_error')
gcv1.fit(train_x,train_y)
gcv1.best_params_

# %%
print('ERROR:')
from sklearn.metrics import mean_absolute_error,mean_squared_error
best_estimator = gcv1.best_estimator_
best_estimator
predlm=best_estimator.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))

# %%
output_df= pd.DataFrame({'Original':test_y, 'Predicted':predlm},columns=["Predicted","Original"])
sns.lmplot(x='Original',y='Predicted',data=output_df,palette='rainbow')

# %% [markdown]
# # Parameter Tuning for KNeighborsRegressor

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_neighbors': [2, 3, 4, 5, 6],  # Number of neighbors to consider
    'weights': ['uniform', 'distance'],  # Weighting scheme for neighbors
    'p': [1, 2]  # Minkowski distance metric (1 for Manhattan, 2 for Euclidean)
}
gcv1=GridSearchCV(KNeighborsRegressor(),param_grid,cv=5,scoring='accuracy')
gcv1.fit(train_x,train_y)
gcv1.best_params_

# %%
print('ERROR:')
from sklearn.metrics import mean_absolute_error,mean_squared_error
best_estimator = gcv1.best_estimator_
best_estimator
predlm=best_estimator.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))

# %%
output_df= pd.DataFrame({'Original':test_y, 'Predicted':predlm},columns=["Predicted","Original"])
sns.lmplot(x='Original',y='Predicted',data=output_df,palette='rainbow')

# %% [markdown]
# # Parameter Tuning for AdaBoostRegressor

# %%
from sklearn.model_selection import GridSearchCV

#creating parameter list to pass in GreadSearchCV
param_grid = {
    'n_estimators': [20, 40, 60, 100, 200],        # Number of base estimators
    'learning_rate': [0.001, 0.01, 0.1, 1.0],   # Learning rate
    'loss': ['linear', 'square', 'exponential']  # Loss function
}
gcv1=GridSearchCV(AdaBoostRegressor(),param_grid,cv=5,scoring='accuracy')
gcv1.fit(train_x,train_y)
gcv1.best_params_

# %%
print('ERROR:')
from sklearn.metrics import mean_absolute_error,mean_squared_error
best_estimator = gcv1.best_estimator_
best_estimator
predlm=best_estimator.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))

# %%
output_df= pd.DataFrame({'Original':test_y, 'Predicted':predlm},columns=["Predicted","Original"])
sns.lmplot(x='Original',y='Predicted',data=output_df,palette='rainbow')

# %% [markdown]
# # Parameter Tuning for GradientBoostingRegressor

# %%
from sklearn.model_selection import GridSearchCV
from scipy.stats import randint

#creating parameter list to pass in GreadSearchCV
param_grid = {
    'n_estimators': [20, 30, 40, 60, 100],
    'max_depth': [3, 4, 5],
    'learning_rate': [0.001, 0.01, 0.1, 0.2],
}
gcv1=GridSearchCV(GradientBoostingRegressor(),param_grid,cv=5,scoring='accuracy')
gcv1.fit(train_x,train_y)
gcv1.best_params_

# %%
print('ERROR:')
from sklearn.metrics import mean_absolute_error,mean_squared_error
best_estimator = gcv1.best_estimator_
best_estimator
predlm=best_estimator.predict(test_x)
print('Mean Absolute Error: ',mean_absolute_error(test_y,predlm))
print('Mean Squared Error: ',mean_squared_error(test_y,predlm))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(test_y,predlm)))

# %%
output_df= pd.DataFrame({'Original':test_y, 'Predicted':predlm},columns=["Predicted","Original"])
sns.lmplot(x='Original',y='Predicted',data=output_df,palette='rainbow')

# %% [markdown]
# ## RandomForestRegressor is our final model. We will now use this model to predict all data and create a DataFrame containing the predicted values alongside the original values.

# %%
best_estimator=RandomForestRegressor(max_depth=30, n_estimators=200)
best_estimator.fit(X,y)
predlm=best_estimator.predict(X)
output_df= pd.DataFrame({'Original':y, 'Predicted':predlm},columns=["Predicted","Original"])
output_df
